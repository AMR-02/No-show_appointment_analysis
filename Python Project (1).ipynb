# %% [markdown]
# # Python Project

# %% [markdown]
# ## Project Title: Medical Appointment no Shows

# %% [markdown]
# ### Dataset Link:
# https://www.kaggle.com/datasets/joniarroba/noshowappointments

# %%
# Import Pandas
import pandas as pd

# %%
# load the File
app_df = pd.read_csv("Medical Appointment No Shows.csv")

# %%
# Execute the DataFrame
app_df
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589980e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262960e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679510e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841190e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572130e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596270e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557660e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213490e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775120e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Number of Rows & Columns
app_df.shape
# Out:
# (110527, 14)

# %%
# Columns
app_df.columns
# Out:
# Index(['PatientId', 'AppointmentID', 'Gender', 'ScheduledDay',
#        'AppointmentDay', 'Age', 'Neighbourhood', 'Scholarship', 'Hipertension',
#        'Diabetes', 'Alcoholism', 'Handcap', 'SMS_received', 'No-show'],
#       dtype='object')

# %%
# Data Type of each Column
app_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %%
# Percentage of Nulls
app_df.isna().sum()/app_df.shape[0]*100
# Out:
# PatientId         0.0
# AppointmentID     0.0
# Gender            0.0
# ScheduledDay      0.0
# AppointmentDay    0.0
# Age               0.0
# Neighbourhood     0.0
# Scholarship       0.0
# Hipertension      0.0
# Diabetes          0.0
# Alcoholism        0.0
# Handcap           0.0
# SMS_received      0.0
# No-show           0.0
# dtype: float64

# %%
# Number of unique values in each column:
app_df.nunique()
# Out:
# PatientId          61744
# AppointmentID     110527
# Gender                 2
# ScheduledDay      103549
# AppointmentDay        27
# Age                  104
# Neighbourhood         81
# Scholarship            2
# Hipertension           2
# Diabetes               2
# Alcoholism             2
# Handcap                5
# SMS_received           2
# No-show                2
# dtype: int64

# %% [markdown]
# This shows that one patient has more than one unique appointment ID each time he/she went to the hospital.

# %% [markdown]
# ## Changing Datatypes

# %% [markdown]
# ### Converting Columns to Datetime Dtype

# %% [markdown]
# Columns that need to be formatted as Datetime:
# - ScheduledDay
# - AppointmentDay

# %%
# Two Columns need to be formatted as Datetime:
# 1. ScheduledDay
app_df.ScheduledDay = pd.to_datetime(app_df.ScheduledDay, format='%Y-%m-%d')

# %%
app_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  datetime64[ns, UTC]
#  4   AppointmentDay  110527 non-null  datetime64[ns, UTC]
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: datetime64[ns, UTC](2), float64(1), int64(8), object(3)
# memory usage: 11.8+ MB

# %%
# Two Columns need to be formatted as Datetime:
# 2. AppointmentDay
app_df.AppointmentDay = pd.to_datetime(app_df.AppointmentDay, format='%Y-%m-%d')

# %%
app_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  datetime64[ns, UTC]
#  4   AppointmentDay  110527 non-null  datetime64[ns, UTC]
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: datetime64[ns, UTC](2), float64(1), int64(8), object(3)
# memory usage: 11.8+ MB

# %%
app_df
# Out:
#            PatientId  AppointmentID Gender              ScheduledDay  \
# 0       2.987250e+13        5642903      F 2016-04-29 18:38:08+00:00
# 1       5.589980e+14        5642503      M 2016-04-29 16:08:27+00:00
# 2       4.262960e+12        5642549      F 2016-04-29 16:19:04+00:00
# 3       8.679510e+11        5642828      F 2016-04-29 17:29:31+00:00
# 4       8.841190e+12        5642494      F 2016-04-29 16:07:23+00:00
# ...              ...            ...    ...                       ...
# 110522  2.572130e+12        5651768      F 2016-05-03 09:15:35+00:00
# 110523  3.596270e+12        5650093      F 2016-05-03 07:27:33+00:00
# 110524  1.557660e+13        5630692      F 2016-04-27 16:03:52+00:00
# 110525  9.213490e+13        5630323      F 2016-04-27 15:09:23+00:00
# 110526  3.775120e+14        5629448      F 2016-04-27 13:30:56+00:00
#
#                   AppointmentDay  Age      Neighbourhood  Scholarship  \
# ...

# %% [markdown]
# ### Converting Columns to Category Dtype

# %% [markdown]
# Columns that need to be formatted as Category:
# - Gender (object)
# - Neighborhood (object)

# %%
cols_to_str = [ "Gender", "Neighbourhood"]
app_df[["Gender", "Neighbourhood"]] = app_df[cols_to_str].astype("category")
# Why dtypes are not changing?

# %%
app_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  category
#  3   ScheduledDay    110527 non-null  datetime64[ns, UTC]
#  4   AppointmentDay  110527 non-null  datetime64[ns, UTC]
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  category
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: category(2), datetime64[ns, UTC](2), float64(1), int64(8), object(1)
# memory usage: 10.3+ MB

# %% [markdown]
# Columns where 0s and 1s need to be re-labelled:
# - Scholarship
# - Hipertension
# - Diabetes
# - Alcoholism
# - Handcap
# - SMS_received
# - No-show

# %%
# Create a dictionary for the columns
# use the syntax df['column'] = df.column.map(dictionary name)

# %%
# For column Scholarship:
ss = {0: "No Scholarship", 1: "On-Scholarship"}

# %%
app_df["Scholarship"] = app_df.Scholarship.map(ss)

# %%
app_df
# Out:
#            PatientId  AppointmentID Gender              ScheduledDay  \
# 0       2.987250e+13        5642903      F 2016-04-29 18:38:08+00:00
# 1       5.589980e+14        5642503      M 2016-04-29 16:08:27+00:00
# 2       4.262960e+12        5642549      F 2016-04-29 16:19:04+00:00
# 3       8.679510e+11        5642828      F 2016-04-29 17:29:31+00:00
# 4       8.841190e+12        5642494      F 2016-04-29 16:07:23+00:00
# ...              ...            ...    ...                       ...
# 110522  2.572130e+12        5651768      F 2016-05-03 09:15:35+00:00
# 110523  3.596270e+12        5650093      F 2016-05-03 07:27:33+00:00
# 110524  1.557660e+13        5630692      F 2016-04-27 16:03:52+00:00
# 110525  9.213490e+13        5630323      F 2016-04-27 15:09:23+00:00
# 110526  3.775120e+14        5629448      F 2016-04-27 13:30:56+00:00
#
#                   AppointmentDay  Age      Neighbourhood     Scholarship  \
# ...

# %%
# For column Hipertension:
Hyperten = {0: "No Hypertension", 1: "Hypertension"}

# %%
app_df["Hipertension"] = app_df.Hipertension.map(Hyperten)

# %%
app_df
# Out:
#            PatientId  AppointmentID Gender              ScheduledDay  \
# 0       2.987250e+13        5642903      F 2016-04-29 18:38:08+00:00
# 1       5.589980e+14        5642503      M 2016-04-29 16:08:27+00:00
# 2       4.262960e+12        5642549      F 2016-04-29 16:19:04+00:00
# 3       8.679510e+11        5642828      F 2016-04-29 17:29:31+00:00
# 4       8.841190e+12        5642494      F 2016-04-29 16:07:23+00:00
# ...              ...            ...    ...                       ...
# 110522  2.572130e+12        5651768      F 2016-05-03 09:15:35+00:00
# 110523  3.596270e+12        5650093      F 2016-05-03 07:27:33+00:00
# 110524  1.557660e+13        5630692      F 2016-04-27 16:03:52+00:00
# 110525  9.213490e+13        5630323      F 2016-04-27 15:09:23+00:00
# 110526  3.775120e+14        5629448      F 2016-04-27 13:30:56+00:00
#
#                   AppointmentDay  Age      Neighbourhood     Scholarship  \
# ...

# %%
# For column Diabetes:
Diabetics = {0: "Non-Diabetic", 1: "Diabetic"}

# %%
app_df["Diabetes"] = app_df.Diabetes.map({0: "Non-Diabetic", 1: "Diabetic"})

# %%
app_df
# Out:
#            PatientId  AppointmentID Gender              ScheduledDay  \
# 0       2.987250e+13        5642903      F 2016-04-29 18:38:08+00:00
# 1       5.589980e+14        5642503      M 2016-04-29 16:08:27+00:00
# 2       4.262960e+12        5642549      F 2016-04-29 16:19:04+00:00
# 3       8.679510e+11        5642828      F 2016-04-29 17:29:31+00:00
# 4       8.841190e+12        5642494      F 2016-04-29 16:07:23+00:00
# ...              ...            ...    ...                       ...
# 110522  2.572130e+12        5651768      F 2016-05-03 09:15:35+00:00
# 110523  3.596270e+12        5650093      F 2016-05-03 07:27:33+00:00
# 110524  1.557660e+13        5630692      F 2016-04-27 16:03:52+00:00
# 110525  9.213490e+13        5630323      F 2016-04-27 15:09:23+00:00
# 110526  3.775120e+14        5629448      F 2016-04-27 13:30:56+00:00
#
#                   AppointmentDay  Age      Neighbourhood     Scholarship  \
# ...

# %%
#For column Alcoholism:
Alcohol = {0: "Non-Alcoholic", 1: "Alcoholic"}

# %%
app_df['Alcoholism'] = app_df.Alcoholism.map(Alcohol)

# %%
app_df
# Out:
#            PatientId  AppointmentID Gender              ScheduledDay  \
# 0       2.987250e+13        5642903      F 2016-04-29 18:38:08+00:00
# 1       5.589980e+14        5642503      M 2016-04-29 16:08:27+00:00
# 2       4.262960e+12        5642549      F 2016-04-29 16:19:04+00:00
# 3       8.679510e+11        5642828      F 2016-04-29 17:29:31+00:00
# 4       8.841190e+12        5642494      F 2016-04-29 16:07:23+00:00
# ...              ...            ...    ...                       ...
# 110522  2.572130e+12        5651768      F 2016-05-03 09:15:35+00:00
# 110523  3.596270e+12        5650093      F 2016-05-03 07:27:33+00:00
# 110524  1.557660e+13        5630692      F 2016-04-27 16:03:52+00:00
# 110525  9.213490e+13        5630323      F 2016-04-27 15:09:23+00:00
# 110526  3.775120e+14        5629448      F 2016-04-27 13:30:56+00:00
#
#                   AppointmentDay  Age      Neighbourhood     Scholarship  \
# ...

# %%
# For column Handcap:
HC = {0: "No Handicap", 1: "Handicapped"}

# %%
app_df['Handcap'] = app_df.Handcap.map(HC)

# %%
app_df
# Out:
#            PatientId  AppointmentID Gender              ScheduledDay  \
# 0       2.987250e+13        5642903      F 2016-04-29 18:38:08+00:00
# 1       5.589980e+14        5642503      M 2016-04-29 16:08:27+00:00
# 2       4.262960e+12        5642549      F 2016-04-29 16:19:04+00:00
# 3       8.679510e+11        5642828      F 2016-04-29 17:29:31+00:00
# 4       8.841190e+12        5642494      F 2016-04-29 16:07:23+00:00
# ...              ...            ...    ...                       ...
# 110522  2.572130e+12        5651768      F 2016-05-03 09:15:35+00:00
# 110523  3.596270e+12        5650093      F 2016-05-03 07:27:33+00:00
# 110524  1.557660e+13        5630692      F 2016-04-27 16:03:52+00:00
# 110525  9.213490e+13        5630323      F 2016-04-27 15:09:23+00:00
# 110526  3.775120e+14        5629448      F 2016-04-27 13:30:56+00:00
#
#                   AppointmentDay  Age      Neighbourhood     Scholarship  \
# ...

# %%
# For column SMS_received:
SMS = {0: "No SMS Received", 1: "SMS Received"}

# %%
app_df["SMS_received"] = app_df.SMS_received.map(SMS)

# %%
app_df
# Out:
#            PatientId  AppointmentID Gender              ScheduledDay  \
# 0       2.987250e+13        5642903      F 2016-04-29 18:38:08+00:00
# 1       5.589980e+14        5642503      M 2016-04-29 16:08:27+00:00
# 2       4.262960e+12        5642549      F 2016-04-29 16:19:04+00:00
# 3       8.679510e+11        5642828      F 2016-04-29 17:29:31+00:00
# 4       8.841190e+12        5642494      F 2016-04-29 16:07:23+00:00
# ...              ...            ...    ...                       ...
# 110522  2.572130e+12        5651768      F 2016-05-03 09:15:35+00:00
# 110523  3.596270e+12        5650093      F 2016-05-03 07:27:33+00:00
# 110524  1.557660e+13        5630692      F 2016-04-27 16:03:52+00:00
# 110525  9.213490e+13        5630323      F 2016-04-27 15:09:23+00:00
# 110526  3.775120e+14        5629448      F 2016-04-27 13:30:56+00:00
#
#                   AppointmentDay  Age      Neighbourhood     Scholarship  \
# ...

# %%
# For Column No-show:
showup = {"No": "Showed up", "Yes": "Missed Appointment"}

# %%
app_df["No-show"] = app_df["No-show"].map(showup)

# %%
app_df
# Out:
#            PatientId  AppointmentID Gender              ScheduledDay  \
# 0       2.987250e+13        5642903      F 2016-04-29 18:38:08+00:00
# 1       5.589980e+14        5642503      M 2016-04-29 16:08:27+00:00
# 2       4.262960e+12        5642549      F 2016-04-29 16:19:04+00:00
# 3       8.679510e+11        5642828      F 2016-04-29 17:29:31+00:00
# 4       8.841190e+12        5642494      F 2016-04-29 16:07:23+00:00
# ...              ...            ...    ...                       ...
# 110522  2.572130e+12        5651768      F 2016-05-03 09:15:35+00:00
# 110523  3.596270e+12        5650093      F 2016-05-03 07:27:33+00:00
# 110524  1.557660e+13        5630692      F 2016-04-27 16:03:52+00:00
# 110525  9.213490e+13        5630323      F 2016-04-27 15:09:23+00:00
# 110526  3.775120e+14        5629448      F 2016-04-27 13:30:56+00:00
#
#                   AppointmentDay  Age      Neighbourhood     Scholarship  \
# ...

# %% [markdown]
# ### Renaming Columns

# %%
app_df.columns
# Out:
# Index(['PatientId', 'AppointmentID', 'Gender', 'ScheduledDay',
#        'AppointmentDay', 'Age', 'Neighbourhood', 'Scholarship', 'Hipertension',
#        'Diabetes', 'Alcoholism', 'Handcap', 'SMS_received', 'No-show'],
#       dtype='object')

# %%
app_df.columns = ['Patient_ID', 
                    'Appointment_ID', 
                    'Gender', 
                    'Scheduled_date', 
                    'Appointment_date', 
                    'Age', 
                    'Neighbourhood', 
                    'Scholarship',
                    'Hypertension',
                    'Diabetes',
                    'Alcoholism',
                    'Handicap',
                    'SMS_received',
                    'No_show']

# %%
app_df
# Out:
#           Patient_ID  Appointment_ID Gender            Scheduled_date  \
# 0       2.987250e+13         5642903      F 2016-04-29 18:38:08+00:00
# 1       5.589980e+14         5642503      M 2016-04-29 16:08:27+00:00
# 2       4.262960e+12         5642549      F 2016-04-29 16:19:04+00:00
# 3       8.679510e+11         5642828      F 2016-04-29 17:29:31+00:00
# 4       8.841190e+12         5642494      F 2016-04-29 16:07:23+00:00
# ...              ...             ...    ...                       ...
# 110522  2.572130e+12         5651768      F 2016-05-03 09:15:35+00:00
# 110523  3.596270e+12         5650093      F 2016-05-03 07:27:33+00:00
# 110524  1.557660e+13         5630692      F 2016-04-27 16:03:52+00:00
# 110525  9.213490e+13         5630323      F 2016-04-27 15:09:23+00:00
# 110526  3.775120e+14         5629448      F 2016-04-27 13:30:56+00:00
#
#                 Appointment_date  Age      Neighbourhood     Scholarship  \
# ...

# %% [markdown]
# ## Questions and Analysis

# %% [markdown]
# ### Question: 01
# What percentage of males and females don't show up to the appointments & which age group do they mostly fall into?

# %%
# Add your code, results of your code, and visualization charts here. 
# Make sure to import matplotlib for plots.

# %%
app_df["Age"].describe().to_frame()
# Out:
#                  Age
# count  110527.000000
# mean       37.088874
# std        23.110205
# min        -1.000000
# 25%        18.000000
# 50%        37.000000
# 75%        55.000000
# max       115.000000

# %%
#%pip install matplotlib

# %%
import matplotlib

# %%
# Checking the distribution of Age using boxplot:
app_df.Age.plot(kind="box")
# Shows that most of the ages fall under the range of 19-58
# Out:
# <Axes: >

# %%
# Defining a function to create new column called 'Age_category':
def Age_cat(age):
    if 0 < age <= 14:
        return "0-14"
    elif 14 < age <= 24:
        return "15-24"
    elif 24 < age <= 40:
        return "25-40"
    elif 41 < age <= 64:
        return "41-64"
    elif age >= 65:
        return "65 & older"

# %%
app_df["Age_category"] = app_df.Age.apply(Age_cat).astype("category")

# %%
app_df
# Out:
#           Patient_ID  Appointment_ID Gender            Scheduled_date  \
# 0       2.987250e+13         5642903      F 2016-04-29 18:38:08+00:00
# 1       5.589980e+14         5642503      M 2016-04-29 16:08:27+00:00
# 2       4.262960e+12         5642549      F 2016-04-29 16:19:04+00:00
# 3       8.679510e+11         5642828      F 2016-04-29 17:29:31+00:00
# 4       8.841190e+12         5642494      F 2016-04-29 16:07:23+00:00
# ...              ...             ...    ...                       ...
# 110522  2.572130e+12         5651768      F 2016-05-03 09:15:35+00:00
# 110523  3.596270e+12         5650093      F 2016-05-03 07:27:33+00:00
# 110524  1.557660e+13         5630692      F 2016-04-27 16:03:52+00:00
# 110525  9.213490e+13         5630323      F 2016-04-27 15:09:23+00:00
# 110526  3.775120e+14         5629448      F 2016-04-27 13:30:56+00:00
#
#                 Appointment_date  Age      Neighbourhood     Scholarship  \
# ...

# %%
app_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Patient_ID        110527 non-null  float64
#  1   Appointment_ID    110527 non-null  int64
#  2   Gender            110527 non-null  category
#  3   Scheduled_date    110527 non-null  datetime64[ns, UTC]
#  4   Appointment_date  110527 non-null  datetime64[ns, UTC]
#  5   Age               110527 non-null  int64
#  6   Neighbourhood     110527 non-null  category
#  7   Scholarship       110527 non-null  object
#  8   Hypertension      110527 non-null  object
#  9   Diabetes          110527 non-null  object
#  10  Alcoholism        110527 non-null  object
#  11  Handicap          110328 non-null  object
#  12  SMS_received      110527 non-null  object
#  13  No_show           110527 non-null  object
#  14  Age_category      105641 non-null  category
# ...

# %%
# Creating a variable to include columns that need to be grouped
cols_to_grp = ["Age_category", "Gender", "No_show"]

# %%
# Filtering the rows with "Missed Appointments"
missed_app = app_df[app_df.No_show == "Missed Appointment"] 
#Single mention of app_df creates a boolean expression. Not what we want
# What we want is; the rows from app_df where value in app_df.No_show is "Missed Appointment".

# %%
#Checking the count of Missed Appointment by Age_category and Gender
missed_counts = missed_app[cols_to_grp].groupby(["Age_category", "Gender"],observed=True).value_counts()
missed_counts.to_frame()
# Out:
#                                         count
# Age_category Gender No_show
# 0-14         F      Missed Appointment   2055
#              M      Missed Appointment   2232
# 15-24        F      Missed Appointment   2503
#              M      Missed Appointment   1037
# 25-40        F      Missed Appointment   3771
#              M      Missed Appointment   1485
# 41-64        F      Missed Appointment   4200
#              M      Missed Appointment   1856
# 65 & older   F      Missed Appointment   1517
#              M      Missed Appointment    716

# %%
# Total count of appointments (missed and non-missed)
total_app = app_df.No_show.value_counts()
total_app
# Out:
# No_show
# Showed up             88208
# Missed Appointment    22319
# Name: count, dtype: int64

# %%
total_app.sum()
# Out:
# np.int64(110527)

# %%
# Total Missed Appointments
total_missed = missed_counts.sum()
total_missed
# Out:
# np.int64(21372)

# %%
# Percentage of Missed Appointments out of total appointments
per_total_missed = (21372/110527)*100
per_total_missed
# Out of all the appointments, 20% of the appointments were missed.
# Out:
# 19.336451726727404

# %%
# Percentage of Missed Appointments by Age and Gender
percent_missed = (missed_counts/total_missed*100).to_frame().sort_values(by='count', ascending=True)
percent_missed
# Out:
#                                             count
# Age_category Gender No_show
# 65 & older   M      Missed Appointment   3.350178
# 15-24        M      Missed Appointment   4.852143
# 25-40        M      Missed Appointment   6.948344
# 65 & older   F      Missed Appointment   7.098072
# 41-64        M      Missed Appointment   8.684260
# 0-14         F      Missed Appointment   9.615385
#              M      Missed Appointment  10.443571
# 15-24        F      Missed Appointment  11.711585
# 25-40        F      Missed Appointment  17.644582
# 41-64        F      Missed Appointment  19.651881

# %%
# Want to edit the values on y-axis:
y_values = ("41-64, F", "25-40, F", "15-24, F", "0-14, M", "0-14, F","41-64, M", "65 & older, F", "25-40, M", "15-24, M", "65 & older, M")

# %%
# Creating plot (bar) for visualization
percent_missed.plot(kind='barh', title='Percentage of Missed Appointments by Age group and Gender', xlabel='Percentage of Missed Appointments', ylabel='Age group & Gender')
# Out:
# <Axes: title={'center': 'Percentage of Missed Appointments by Age group and Gender'}, xlabel='Percentage of Missed Appointments', ylabel='Age group & Gender'>

# %% [markdown]
# ### **Conclusion:**
# - The analysis shows that around 20% of all the appointments have been missed by patients.
# - Missed appointments across gender and age groups were analyzed and following key observations were made:
#   1. Women rank the highest in terms of missing medical appointments across all age groups, with majority of them falling in the category of age 41-64 and 25-40 (25-64).
#   2. The higher no-show rates among women could possibly be due to factors such as work, care-giving responsibilities or a sensitive health condition.
#   3. Men have considerably lower rates of missed appointments, with the least rate being men aged 65 years and older.
#
# ### **Recommendation:**
# - Age & gender are important factors when it comes to appointment attendance. Healthcare providers could investigate the cause of women missing aged 25-65 since they have the higher no-show rates.
# - Flexible appointment schedules could be considered for working women.

# %% [markdown]
# ### Question: 02
# How do the following factors influence patients' medical appointment attendance?
# - Factors:
# 1. WaitingDay
# 2. Scholarship
# 3. Handicap
# 4. Alcoholism

# %%
# Add your code, results of your code, and visualization charts here. 
# Make sure to import matplotlib for plots.

# %%
# Extract Date:
app_df['Scheduled_date'] = app_df.Scheduled_date.dt.date

# %%
app_df['Appointment_date'] = app_df.Appointment_date.dt.date

# %%
app_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Patient_ID        110527 non-null  float64
#  1   Appointment_ID    110527 non-null  int64
#  2   Gender            110527 non-null  category
#  3   Scheduled_date    110527 non-null  object
#  4   Appointment_date  110527 non-null  object
#  5   Age               110527 non-null  int64
#  6   Neighbourhood     110527 non-null  category
#  7   Scholarship       110527 non-null  object
#  8   Hypertension      110527 non-null  object
#  9   Diabetes          110527 non-null  object
#  10  Alcoholism        110527 non-null  object
#  11  Handicap          110328 non-null  object
#  12  SMS_received      110527 non-null  object
#  13  No_show           110527 non-null  object
#  14  Age_category      105641 non-null  category
# ...

# %%
app_df
# Out:
#           Patient_ID  Appointment_ID Gender Scheduled_date Appointment_date  \
# 0       2.987250e+13         5642903      F     2016-04-29       2016-04-29
# 1       5.589980e+14         5642503      M     2016-04-29       2016-04-29
# 2       4.262960e+12         5642549      F     2016-04-29       2016-04-29
# 3       8.679510e+11         5642828      F     2016-04-29       2016-04-29
# 4       8.841190e+12         5642494      F     2016-04-29       2016-04-29
# ...              ...             ...    ...            ...              ...
# 110522  2.572130e+12         5651768      F     2016-05-03       2016-06-07
# 110523  3.596270e+12         5650093      F     2016-05-03       2016-06-07
# 110524  1.557660e+13         5630692      F     2016-04-27       2016-06-07
# 110525  9.213490e+13         5630323      F     2016-04-27       2016-06-07
# 110526  3.775120e+14         5629448      F     2016-04-27       2016-06-07
#
# ...

# %%
# Calculating waiting days:
app_df['Waiting_day'] = (app_df.Scheduled_date) - (app_df.Appointment_date)
app_df['Waiting_day']
# Out:
# 0                   0:00:00
# 1                   0:00:00
# 2                   0:00:00
# 3                   0:00:00
# 4                   0:00:00
#                 ...
# 110522    -35 days, 0:00:00
# 110523    -35 days, 0:00:00
# 110524    -41 days, 0:00:00
# 110525    -41 days, 0:00:00
# 110526    -41 days, 0:00:00
# Name: Waiting_day, Length: 110527, dtype: object

# %%
# To remove negative values:

# %% [markdown]
# ### Question: 03
# Does sending an SMS reminder reduce the likelihood of a no-show?

# %%
# Add your code, results of your code, and visualization charts here. 
# Make sure to import matplotlib for plots.

# %%
# Creating a variable to include columns that need to be grouped
cols_to_grp = ['SMS_received', 'No_show']
app_df[cols_to_grp].groupby(by=['SMS_received', 'No_show']).No_show.value_counts().to_frame()
# Out:
#                                     count
# SMS_received    No_show
# No SMS Received Missed Appointment  12535
#                 Showed up           62510
# SMS Received    Missed Appointment   9784
#                 Showed up           25698

# %%
# Saving the above result in a variable called sms_app
sms_app = app_df[cols_to_grp].groupby(by=['SMS_received', 'No_show']).No_show.value_counts().to_frame()
sms_app
# Out:
#                                     count
# SMS_received    No_show
# No SMS Received Missed Appointment  12535
#                 Showed up           62510
# SMS Received    Missed Appointment   9784
#                 Showed up           25698

# %%
# Total Appointment count: 
total_count = sms_app.sum()
total_count
# Out:
# count    110527
# dtype: int64

# %%
# Percentage of counts: 
per_sms_app = (sms_app/total_count)*100
per_sms_app
# Out:
#                                         count
# SMS_received    No_show
# No SMS Received Missed Appointment  11.341120
#                 Showed up           56.556317
# SMS Received    Missed Appointment   8.852136
#                 Showed up           23.250427

# %% [markdown]
# ### **Conclusion:**
# ### **Recommendation:**
